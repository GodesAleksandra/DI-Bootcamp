# %% [markdown]
# <a href="https://colab.research.google.com/github/GodesAleksandra/DI-Bootcamp/blob/main/Exercises_XP_Prompt_Engineering_Student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercises XP: Prompt Engineering
# Use this guided notebook and fill each TODO before running cells.

# %% [markdown]
# ## What you'll learn
# - Analyze and improve vague prompts for clarity and usefulness.
# - Apply role, constraint, tone, and structure techniques.
# - Build multi-part prompts that control output format and reduce hallucinations.

# %% [markdown]
# ## What you'll build
# - A polished marketing prompt.
# - A structured educational prompt (summary + quiz) for Google Slides.
# - Context-rich prompts for finance updates, support chatbots, and marketing blurbs.

# %% [markdown]
# ## Exercise 1: Rewrite and Optimize a Vague Prompt
# **Scenario**: Manager asks for a LinkedIn post about FlowNest with the vague prompt `"Write something about productivity tips."`

# %% [markdown]
# ### Tasks
# - Identify 3 critical issues with the prompt.
# - Rewrite it using: role prompting, clear instructions, and format/tone/length constraints.
# - Add a final line to make it reusable for future social posts.

# %%
# TODO: list three critical issues with the vague prompt
critical_issues = [
    'Missing role and context',
    'No platform or audience targeting',
    'Lack of structural and length constraints',
]
critical_issues

# %%
# TODO: rewrite the prompt using role, instructions, and constraints
rewritten_prompt = 'Act as an expert B2B Social Media Marketer and Copywriter specializing in workplace productivity software. Provide 3 actionable productivity tips that focus on time-blocking, minimizing context-switching, or deep work. Use short, punchy paragraphs, ample white space, bullet points for the tips. Use this format whenever we promote productivity tools on social media.'
rewritten_prompt

# %% [markdown]
# ## Exercise 2: Multi-Part Prompt for Quiz Generation
# **Scenario**: Create an educational prompt for 7th graders about volcanic eruptions.

# %% [markdown]
# ### Tasks
# - Ask for: 2-bullet summary + 3 MCQs (1 correct, 2 distractors).
# - Require friendly tone, simple vocab (11?13 y/o), and Google Slides-ready output.
# - Explain 3 ways your prompt improves on: `Make a quiz for kids about this article.`

# %%
# TODO: write the full multi-part prompt
quiz_prompt = 'Act as an experienced, engaging middle school Science Teacher who specializes in making complex earth science topics fun and accessible. You are provided with a short article about volcanic eruptions for a 7th-grade class (ages 11–13). Create educational content based on the article that is ready to be pasted into a Google Slides presentation. Exactly 2 simple, punchy, and clear bullet points summarizing the core message of the article. Generate 3 multiple-choice questions tailored to 11-13-year-olds, include the question text and 3 options: 1 correct answer and 2 plausible, but incorrect distractors. Use friendly tone and simple, age-appropriate language.'
quiz_prompt

# %%
# TODO: explain three improvements over the vague prompt
improvements = [
    'Eliminates age ambiguity (targeted complexity)',
    'Enforces rigid structuring for questions and options',
    'Optimizes formatting for immediate classroom use',
]
improvements

# %% [markdown]
# ## Exercise 3: Add Context, Get Better Results
# **Scenario**: Intern's vague request: `Summarize this report.`

# %% [markdown]
# ### Tasks
# 1) Fill the table by marking missing context and what to add.
# 2) Rewrite the prompt including at least 4 context types (role, audience, purpose, input, format/style, constraints).

# %%
# TODO: fill the context table
context_table = {
    'Role': {'missing': True, 'add': 'Instruct the AI to act as a Senior Financial Analyst'},
    'Audience': {'missing': True, 'add': 'Specify that the listeners are the non-technical executive team and board members.'},
    'Purpose': {'missing': True, 'add': 'Define the goal: preparing a 3-minute spoken presentation summary for a monthly update.'},
    'Input Source': {'missing': True, 'add': 'Explicitly reference the attached monthly finance report documents.'},
    'Format/Style': {'missing': True, 'add': 'Request structural elements like 3 key bullet-point takeaways with a clear hook and conclusion.'},
    'Constraints': {'missing': True, 'add': 'Enforce a strict word count (max 300 words for a 3-minute speech) and a requirement to include exact financial figures.'},
}
context_table

# %%
# TODO: rewrite the intern's prompt with richer context
finance_prompt = 'Act as a Senior Financial Analyst with exceptional skills in executive communication. The audience consists of a non-technical executive team. Summarize the attached monthly financial report into a highly structured, data-driven brief. Maximum 300 words. Use professional tone. Use bolding on key numbers and clear bullet points for the 3 core takeaways to make it highly scannable.'
finance_prompt

# %% [markdown]
# ## Exercise 4: Match Prompt to Purpose
# Pick a style (Exploratory, Structured, Conversational, Functional) to build a customer-support chatbot prompt.

# %% [markdown]
# ### Tasks
# - Write the full prompt in the chosen style.
# - Identify 2 features that prove it matches the style.
# - Justify why this style fits better than the others.

# %%
# TODO: choose a style and write the prompt
chosen_style = 'Structured'
prompt_template = 'Act as an empathetic, efficient Customer Support AI Agent for our online clothing store, "TrendNest". Resolve a customer\'s inquiry regarding a delayed package or missing order with precision.  Follow this exact multi-step resolution process: \
Step 1: Validate the customer\'s frustration with a short, sincere apology. Use their name.\
Step 2: State the exact current tracking status and estimated delivery window clearly. \
Step 3: Provide a proactive resolution based on status:\
  - If delayed < 3 days: Ask for patience and offer a $5 store credit code (NEST5).\
  - If delayed > 3 days or lost: Offer an immediate free replacement shipment or a full refund.\
Step 4: Sign off by asking if there is anything else you can assist with, using "Best regards, TrendNest Support.\
Use professional tone, be polite.\
Present the final response in three clear, short paragraphs separated by line breaks. Do not mix steps into a single block of text."
'
key_style_features = ['Sequential Multi-Step Workflow', 'Strict Layout Constraints']
justification = 'The Structured style is vastly superior to the other three styles for this specific e-commerce customer support use case:\
While a conversational tone sounds human, it tends to be overly wordy, unpredictable, and prone to losing sight of the actual resolution mechanism. Customers with delivery issues want quick answers and clear options, not lengthy small talk.\
Exploratory prompts are designed for brainstorming and open-ended ideation. In customer service, open-ended variation is a liability. The chatbot must follow specific company refund/credit guidelines, leaving zero room for creative imagination.\
A purely functional prompt focuses solely on data transformation or extraction (e.g., parsing a tracking code) without considering formatting rules, brand voice, or customer empathy steps, leading to cold and robotic automated messages.'

# %% [markdown]
# ## Exercise 5: Prompt Refinement Challenge ? Control Style, Structure, and Length
# **Scenario**: Write a prompt for PulseOne Mini smartwatch email blurb.

# %% [markdown]
# ### Tasks
# 1) Enforce: friendly tone, bullet points, max 50 words, mention battery life, fitness tracking, Bluetooth.
# 2) After running, evaluate adherence and revise with stronger constraints if needed.

# %%
# TODO: initial prompt with strict constraints
pulseone_prompt_v1 = 'Act as an enthusiastic, friendly Product Marketing Copywriter for our wearable tech company. Write a product blurb for our new smartwatch, the PulseOne Mini, to be used in an upcoming email campaign.\
Use warm, energetic, and highly friendly tone. Write a 1-sentence opening hook, followed by exactly 3 short bullet points. You must explicitly mention these 3 features: battery life, fitness tracking, and Bluetooth compatibility. Do not exceed 50 words total for the entire response. Count your words before outputting.'

# %%
# TODO: self-evaluate after running the prompt (did it meet constraints?)
eval_v1 = {
    'word_count_ok': Yes,
    'features_covered': Yes,
    'tone_ok': Yes,
    'notes': '',
}

# %%
# TODO: revised prompt if constraints were missed
pulseone_prompt_v2 = '[IMPROVE IF NEEDED]'

# %% [markdown]
# ## Exercise 6: Hallucination Spotting and Mitigation
# **Scenario**: Model added an unsupported claim in a climate/marine article summary.

# %% [markdown]
# ### Tasks
# 1) Prompt the model to avoid hallucinations using only provided text.
# 2) Rewrite with verification language.
# 3) List 2 mitigation strategies.
# 4) Name 2 domains where hallucinations are risky and why.

# %%
# TODO: baseline anti-hallucination prompt
no_hallucination_prompt = 'Act as a strict Fact-Checking Editor. Summarize the data using ONLY the provided text below. Rely exclusively on the clear facts explicitly stated in the text above. Do not use any outside knowledge, external assumptions, or creative interpretations. If a claim is not written verbatim or directly backed by the source text, it is completely forbidden to include it. If the provided text does not contain the answer, or if you are uncertain, you must state exactly this: "The provided text does not contain this information." Do not attempt to guess, fill in the blanks, or offer a plausible alternative.'

# %%
# TODO: verification-focused rewrite
verification_prompt = 'Act as an objective, precise Scientific Research Assistant. Summarize the attached peer-reviewed article on climate change and marine biodiversity. Only include claims explicitly stated in the article. Every single fact, number, or projection you output must be directly traceable to a sentence in the source text. Do not assume, extrapolate, or bring in outside knowledge. If a statement cannot be verified directly by the provided text, it must be completely excluded. If uncertain, or if the text does not explicitly mention the information, state that the information is not available. Do not attempt to guess or create a plausible answer.'

# %%
# TODO: list mitigation strategies and risky domains
mitigation_strategies = ['Explicit Grounding & Negative Constraints', 'Standardizing the Uncertainty Response']
risky_domains = {
    'domain_1': {'name': 'Healthcare / Medicine', 'why': 'Hallucinated data in a medical context can lead to incorrect drug dosages, misdiagnosed symptoms, or false treatment plans. Because AI outputs sound highly confident, a medical practitioner or patient relying blindly on hallucinated text could make decisions that directly threaten human life.'},
    'domain_2': {'name': 'Legal', 'why': 'In the legal field, arguments rely heavily on exact case law, precedents, and statutes. Hallucinating a non-existent legal case or misquoting a statue can lead to a lawyer presenting fake evidence in court, resulting in severe professional malpractice penalties, thrown-out cases, or wrongful convictions.'},
}
