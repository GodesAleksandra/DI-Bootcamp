# %% [markdown]
# <a href="https://colab.research.google.com/github/GodesAleksandra/DI-Bootcamp/blob/main/Exercises_XP_Open_Source_LLMs_Student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercises XP: Open-Source LLM Strategy (Student)
# Use this guided notebook and fill each TODO. Run it in Colab if you prefer; GPU not required unless you try optional model runs.

# %% [markdown]
# ## What you'll learn
# - Identify degrees of openness in LLMs and what each enables.
# - Understand and compare open-source licenses.
# - Assess strengths/trade-offs of open LLMs for specific constraints (CPU, math, multilingual).
# - Evaluate which models fit given hardware and licensing needs.
# - Use open tools/leaderboards to guide model selection.
# - Plan deployment trade-offs (local vs. cloud).

# %% [markdown]
# ## What you will create
# - Comparative LLM openness analysis (table + paragraph + healthcare prompt answer).
# - Licensing compatibility checklist for SaaS products.
# - Quiz-style reflection on LLM selection.
# - Local deployment readiness checklist + upgrade notes.
# - Benchmark-based model match guide.
# - Hardware upgrade plan / cost-benefit comparison (local vs. cloud).

# %% [markdown]
# ## Exercise 1: Open Source Levels Reflection
# **Use:** Fully Open, Weights Released, Architecture Only; model components; fine-tuning/domain adaptation; healthcare compliance.
#
# **Step-by-step**
# 1) Gather definitions for the three openness levels.
# 2) Identify key characteristics (what is open; what you can/cannot do).
# 3) Compare side by side in a table (what's open vs. impact).
# 4) Write a 3?5 sentence comparative paragraph.
# 5) Answer the healthcare prompt (1?2 sentences) about retraining on clinical data.
#
# **Deliverables:** paragraph + healthcare answer.

# %%
# TODO: capture definitions and key characteristics
open_source_levels = {
    "Fully Open": {
        "definition": "TODO: define Fully Open",
        "what_is_open": ["model’s architecture", "weights", "training code", "training data"],
        "what_you_can_do": ["reproduce the model from scratch", "fully understand and audit the model", "fine-tune or retrain it"],
        "what_you_cannot_do": ["TODO", "TODO"],
    },
    "Weights Released": {
        "definition": "TODO: define Weights Released",
        "what_is_open": ["TODO", "TODO"],
        "what_you_can_do": ["TODO", "TODO"],
        "what_you_cannot_do": ["TODO", "TODO"],
    },
    "Architecture Only": {
        "definition": "TODO: define Architecture Only",
        "what_is_open": ["TODO", "TODO"],
        "what_you_can_do": ["TODO", "TODO"],
        "what_you_cannot_do": ["TODO", "TODO"],
    },
}
open_source_levels

# %%
# TODO: capture definitions and key characteristics
open_source_levels = {
    "Fully Open": {
        "definition": "TODO: define Fully Open",
        "what_is_open": ["model’s architecture", "weights", "training code", "training data"],
        "what_you_can_do": ["reproduce the model from scratch", "fully understand and audit the model", "fine-tune or retrain "],
        "what_you_cannot_do": ["TODO", "TODO"],
    },
    "Weights Released": {
        "definition": "TODO: define Weights Released",
        "what_is_open": ["TODO", "TODO"],
        "what_you_can_do": ["TODO", "TODO"],
        "what_you_cannot_do": ["TODO", "TODO"],
    },
    "Architecture Only": {
        "definition": "TODO: define Architecture Only",
        "what_is_open": ["TODO", "TODO"],
        "what_you_can_do": ["TODO", "TODO"],
        "what_you_cannot_do": ["TODO", "TODO"],
    },
}
open_source_levels

# %%
# TODO: capture definitions and key characteristics
open_source_levels = {
    "Fully Open": {
        "definition": "an AI system where every core component and asset is made publicly available under an open-source license",
        "what_is_open": ["model’s architecture", "weights", "training code", "training data"],
        "what_you_can_do": ["reproduce the model from scratch", "fully understand and audit the model", "fine-tune or retrain the model"],
        "what_you_cannot_do": [""],
    },
    "Weights Released": {
        "definition": "an AI system where the pre-trained numerical parameters and biases (the weights) are made publicly downloadable, but the underlying training datasets and data pipelines remain private",
        "what_is_open": ["the pre-trained model weights", "the model architecture code", "basic inference scripts"],
        "what_you_can_do": ["run the model in your own applications", "fine-tune the model on your own dataset", "deploy it for specific use cases"],
        "what_you_cannot_do": ["trace back how the model was trained", "fully investigate hidden biases or issues"],
    },
    "Architecture Only": {
        "definition": "provides only the structural blueprint and neural network configuration code, without any pre-trained weights or training data",
        "what_is_open": ["the source code defining the network layers", "hyperparameters", "structural setup"],
        "what_you_can_do": ["understand the model design", "train the model yourself (but you’d need enormous computing power and a large dataset)"],
        "what_you_cannot_do": ["use the model immediately out of the box (because there are no pre-trained weights, any input you give it will result in completely random, useless noise until you spend the time and money to train it)"],
    },
}
open_source_levels

# %%
# TODO: fill the comparison table (keep markdown formatting)
comparison_table = """| Openness level | What's open? | Impact on retraining/modifying |
| --- | --- | --- |
| Fully Open | Training data, source code, model architecture, and final weights | Maximum control and transparency. Allows full auditability, retraining from scratch, and deep optimization, though it requires massive computing power |
| Weights Released | Model architecture and pre-trained parameters (weights) | High customization with lower compute. Enables immediate deployment, fine-tuning, and domain adaptation, but the training data pipeline remains a black box |
| Architecture Only | The structural blueprint/code of the neural network layers | No functional model provided. Users must invest heavy compute and data to train the model from scratch, but it allows complete data privacy from day one |"""
print(comparison_table)

# %%
# TODO: 3?5 sentence comparative paragraph
comparative_paragraph = """Fully Open models provide the ultimate level of transparency and reproducibility by sharing everything from the raw training data to the final weights. In contrast, Weights Released models (like Llama or Mistral) skip sharing the data pipeline but deliver a functional, pre-trained brain that organizations can immediately deploy or fine-tune at a fraction of the cost. Finally, Architecture Only releases provide nothing more than a structural blueprint, forcing users to supply both the massive datasets and the compute required to train the network entirely from scratch."""
print(comparative_paragraph)

# %%
# TODO: 1?2 sentence healthcare prompt answer
healthcare_prompt_answer = """To retrain an AI model on sensitive clinical data while ensuring strict healthcare compliance (like HIPAA or GDPR), a Weights Released or Architecture Only model should be deployed entirely within a secure, on-premise, or private cloud environment. This ensures that protected health information (PHI) never leaves the institution's secure boundary during fine-tuning or domain adaptation."""
print(healthcare_prompt_answer)

# %% [markdown]
# ## Exercise 2: License Check for SaaS Use
# **Use:** HF model pages; permissive vs. copyleft; commercial clauses; restrictions (MAU caps, attribution, export controls).
#
# **Step-by-step**
# 1) Select two HF models (e.g., Mistral-7B-Instruct, Llama-2-7b-chat-hf) and note URLs.
# 2) Locate the License field and copy the name.
# 3) Determine if commercial use is allowed/restricted/prohibited; note conditions.
# 4) Identify extra restrictions (MAU caps, attribution, export/geography).
# 5) Build the markdown checklist with your findings.
#
# **Deliverables:** model names + URLs + completed checklist.

# %%
# TODO: record model metadata from the HF pages
license_checklist = [
    {
        "model": "mistralai/Mistral-7B-Instruct-v0.3",
        "url": "https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.3",
        "license": "apache-2.0",
        "commercial_use": "Yes",
        "restrictions": ["Include the original Apache 2.0 copyright notice", "Retain the liability disclaimer and state modifications if code/weights are changed"],
    },
    {
        "model": "meta-llama/Llama-2-7b-chat-hf",
        "url": " https://huggingface.co/meta-llama/Llama-2-7b-chat-hf",
        "license": "Llama 2 Community License Agreement",
        "commercial_use": "Conditional",
        "restrictions": ["Requires a custom Meta license if Monthly Active Users (MAU) exceed 700 million",
                         "Prohibited from using model outputs to train competing large language models",
                         "Must prominent display 'Built with Meta Llama 2' attribution in user-facing applications",
                         "Strict compliance required with United States export control and California laws"],
    },
]
license_checklist

# %% [markdown]
# ### Checklist template (fill and keep in markdown)
# - [ ] **Model 1**
#   - Type of license:
#     - [ ] License name
#   - Commercial use allowed:
#     - [ ] Yes / No / Conditional
#   - Restrictions:
#     - [ ] Restriction #1
#     - [ ] Restriction #2
# - [ ] **Model 2**
#   - Type of license:
#     - [ ] License name
#   - Commercial use allowed:
#     - [ ] Yes / No / Conditional
#   - Restrictions:
#     - [ ] Restriction #1
#     - [ ] Restriction #2

# %% [markdown]
# ## Exercise 3: LLM Matchmaker Challenge
# **Use:** CPU inference, low-end laptops, multilingual needs; HF filters; size <=7B; benchmarks (BoolQ, GSM8K, FLORES-200).
#
# **Step-by-step**
# 1) Analyze team needs (LegalTech CPU logic; EdTech math/logic low-end; Global NGO multilingual >=5 langs).
# 2) Apply HF filters (cpu/quantized, logic/math/multilingual tags, size <=7B).
# 3) List 3?5 candidates per team with params/arch/quantization/benchmarks.
# 4) Compare top 2 per team and pick the best model with justification.
# 5) Fill the table with your picks.
#
# **Deliverables:** filter summary + filled picks table.

# %%
# TODO: jot down search filters or URLs for each team
filters_by_team = {
    "LegalTech": ["size_categories:1B<7B",
                  "format:gguf",
                  "tags:text-generation",
                  "query:qwen2.5 OR mistral OR llama-3",
                  "notes: Prioritizing strong base instruction architectures with high logic density (BoolQ) for CPU inference."],
    "EdTech": ["size_categories:1B<4B",
                "format:gguf",
                "tags:text-generation",
                "query:deepseek-r1 OR qwen-math OR phi-3.5",
                "notes: Focusing on models with native Chain-of-Thought (CoT) or math fine-tuning for step-by-step tutoring."],
    "Global NGO": ["size_categories:1B<7B",
                  "format:gguf",
                  "tags:multilingual",
                  "query:aya OR qwen2.5 OR gemma-2",
                  "notes: Selecting models with massive vocabulary tokenizers to optimize multi-language FLORES-200 performance."],
}
filters_by_team

# %%
# TODO: candidate lists per team (3?5 each)
candidates_by_team = {
    "LegalTech": [
        {
            "model": "Qwen2.5-7B-Instruct",
            "params_b": "7.6B",
            "arch": "Qwen2",
            "optimization": "GGUF (Q4_K_M)",
            "benchmarks": "BoolQ: ~88.5%"
        },
        {
            "model": "Llama-3-8B-Instruct",
            "params_b": "8.0B",
            "arch": "Llama-3",
            "optimization": "GGUF (Q4_K_M)",
            "benchmarks": "BoolQ: ~87.2%"
        },
        {
            "model": "Mistral-7B-Instruct-v0.3",
            "params_b": "7.2B",
            "arch": "Mistral",
            "optimization": "GGUF (Q4_K_M)",
            "benchmarks": "BoolQ: ~84.3%"
        },
    ],
    "EdTech": [
        {
            "model": "DeepSeek-R1-Distill-Qwen-7B",
            "params_b": "7.6B",
            "arch": "Qwen2.5 (Distilled Reasoning)",
            "optimization": "GGUF (Q4_K_S)",
            "benchmarks": "GSM8K: ~91.2%"
        },
        {
            "model": "Qwen2.5-Math-7B-Instruct",
            "params_b": "7.6B",
            "arch": "Qwen2.5-Math",
            "optimization": "GGUF (Q4_K_M)",
            "benchmarks": "GSM8K: ~89.8%"
        },
        {
            "model": "Phi-3.5-mini-instruct",
            "params_b": "3.8B",
            "arch": "Phi-3",
            "optimization": "GGUF (Q5_K_M)",
            "benchmarks": "GSM8K: ~86.2%"
        },
    ],
    "Global NGO": [
        {
            "model": "Qwen2.5-7B-Instruct",
            "params_b": "7.6B",
            "arch": "Qwen2",
            "optimization": "GGUF (Q4_K_M)",
            "benchmarks": "FLORES-200: Top-Tier (29+ Langs)"
        },
        {
            "model": "Gemma-2-2B-IT",
            "params_b": "2.6B",
            "arch": "Gemma-2",
            "optimization": "GGUF (Q6_K)",
            "benchmarks": "FLORES-200: Mid-High (10+ Langs)"
        },
        {
            "model": "Aya-23-8B",
            "params_b": "8.0B",
            "arch": "Cohere (Command)",
            "optimization": "GGUF (Q4_K_M)",
            "benchmarks": "FLORES-200: Robust (23 Langs)"
        },
    ],
}
candidates_by_team

# %%
# TODO: final picks table (keep markdown formatting)
matchmaker_table = """| Team | Needs | Your Pick |

| --- | --- | --- |
| LegalTech | Fast model for logic-heavy chatbot on CPU | **Qwen2.5-7B-Instruct** (GGUF Q4_K_M) |
| EdTech | Logic/math-focused LLM on low-end laptops | **DeepSeek-R1-Distill-Qwen-7B** (GGUF Q4_K_S) |
| Global NGO | Model that speaks 5+ languages well | **Qwen2.5-7B-Instruct** (GGUF Q4_K_M) |"""
print(matchmaker_table)

# %% [markdown]
# ## Exercise 4: Local Readiness Audit
# **Use:** RAM/disk/OS; llama.cpp requirements (AVX/SSE, cmake/make/gcc/clang); quantized formats (GGUF).
#
# **Step-by-step**
# 1) Gather system specs (RAM, free disk, OS type/version).
# 2) Fill the audit table and mark ?/?.
# 3) Check llama.cpp readiness (instruction sets, compilers, build tools).
# 4) Identify upgrade needs for each ?.
#
# **Deliverables:** filled table + upgrade summary.

# %%
# TODO: your measured system specs
system_specs = {
    "ram_gb": "12",
    "free_disk_gb": "3",
    "os": "WSL2",
}
system_specs

# %%
# TODO: readiness table (keep markdown formatting)
readiness_table = """| Requirement | Your System Specs | Meets Requirement? |
| --- | --- | --- |
| RAM (>= 16 GB) | 12 | NO |
| Free Disk Space (>= 40 GB) | 3 | NO |
| OS (Linux/WSL2) | WSL2 | Yes |"""
print(readiness_table)

# %%
# TODO: llama.cpp readiness notes
llama_cpp_readiness = {
    "cpu_instruction_support": "AVX, SSE",
    "tooling": ["cmake", "gcc/clang"],
    "other_requirements": "Git, C++17 compliant compiler, Python 3.9+ (for model conversion scripts)",
}
llama_cpp_readiness

# %%
# TODO: upgrade or mitigation actions
upgrade_actions = ["clean old files or attach new storage", "add modules or use swap file (not recommended)"]
upgrade_actions

# %% [markdown]
# ## Exercise 5: Benchmark-Based Model Explorer
# **Use:** Open LLM Leaderboard; HellaSwag and MMLU scores; license types; use-case mapping.
#
# **Step-by-step**
# 1) Pick three models from the leaderboard with different strengths (high HellaSwag, high MMLU, balanced).
# 2) Record HellaSwag, MMLU, license, and ideal use case.
# 3) Fill the comparison table.
# 4) Optional: 1?2 sentence reflection on why benchmarks matter.
# 5) Quiz-style reflection: write 3 short Q&A items about choosing models for different constraints.
#
# **Deliverables:** model list + filled table + quiz-style reflection (+ optional reflection paragraph).

# %%
# TODO: leaderboard picks
leaderboard_models = [
    {"model": "TODO", "url": "", "hellaswag": "", "mmlu": "", "license": "", "ideal_use_case": ""},
    {"model": "TODO", "url": "", "hellaswag": "", "mmlu": "", "license": "", "ideal_use_case": ""},
    {"model": "TODO", "url": "", "hellaswag": "", "mmlu": "", "license": "", "ideal_use_case": ""},
]
leaderboard_models

# %%
# TODO: comparison table (keep markdown formatting)
benchmark_table = """| Model Name | HellaSwag Score | MMLU Score | License Type | Ideal Use Case |
| --- | --- | --- | --- | --- |
|  |  |  |  |  |
|  |  |  |  |  |
|  |  |  |  |  |"""
print(benchmark_table)

# %% [markdown]
# ### Optional reflection
# 1?2 sentences on why benchmarks?not hype?should guide model choice.

# %%
# TODO: quiz-style reflection (3 short Q&A items on model selection)
quiz_reflection = [
    {"question": "TODO", "answer": "TODO"},
    {"question": "TODO", "answer": "TODO"},
    {"question": "TODO", "answer": "TODO"},
]
quiz_reflection

# %% [markdown]
# ## Exercise 6: Cloud vs. Local Deployment Plan
# **Use:** local vs. cloud cost/latency/scalability/security/maintenance; optional Colab timing.
#
# **Step-by-step**
# 1) Draft 5 bullets pairing local vs. cloud pros/cons.
# 2) Optional: run a 7B model on Colab; note model and response time.
# 3) Summarize Colab observation if you ran it.
#
# **Deliverables:** 5 bullets; optional Colab report (model + time).

# %%
# TODO: 5 bullets mixing pros/cons (one line each)
pros_and_cons = [
    "TODO",
    "TODO",
    "TODO",
    "TODO",
    "TODO",
]
pros_and_cons

# %%
# Optional: Colab timing note
colab_run = {
    "model_tested": "TODO",
    "response_time_seconds": "TODO",
    "notes": "TODO",
}
colab_run
